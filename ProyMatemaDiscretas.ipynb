# %%
import numpy as np
import csv 
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import HTML
from pandas import DataFrame

# %%
data = pd.read_csv('D:/Ing Sistemas 2020/Semestres/semestre 2020-1/Proyecto/vertices.csv', delimiter =r";", encoding='latin1')
dvc = pd.DataFrame(data=data)
dvc.head()
# Out:
#    Punto_Muestreo     Tipo Nombre
# 0               1  Drenaje      A
# 1               2  Drenaje      B
# 2               3  Drenaje      C
# 3               4  Drenaje      D
# 4               5  Drenaje      E

# %%
data = pd.read_csv('D:/Ing Sistemas 2020/Semestres/semestre 2020-1/Proyecto/Datosproyc.csv', delimiter =r";", encoding='latin1')
dar = pd.DataFrame(data=data)
dar.head()
# Out:
#    Arista Vertice Inicio Vertice Final  Distancia (km)
# 0       1             10             P        1.128768
# 1       2              P            10        1.128768
# 2       3              O            10        1.372428
# 3       4             10             O        1.372428
# 4       5              N             9        1.157236

# %%
import matplotlib.pyplot as plt
import networkx as nx
import graphviz as pgv
Dar=nx.DiGraph()
for row in dvc.iterrows():
    Dar.add_edge(row[1]["Vertice Inicio"],
                row[1]["Vertice Final"])

# %%
DVC.nodes(data=True)
# Out:
# NodeDataView({'10': {}, 'P': {}, 'O': {}, 'N': {}, '9': {}, '4': {}, '8': {}, 'M': {}, '3': {}, '7': {}, '1': {}, 'I': {}, 'L': {}, 'Q': {}, '5': {}, 'R': {}, '2': {}, '6': {}, 'D': {}, 'C': {}, 'B': {}, 'A': {}, 'H': {}, 'W': {}, 'V': {}, 'S': {}, 'T': {}, 'U': {}, 'J': {}, 'K': {}, 'G': {}, 'F': {}, 'E': {}})

# %%
nx.draw_circular(Dar,
                node_color="lightblue",
                edge_color="black", 
                font_size=15, 
                width=0.5, 
                with_labels=True, 
                node_size=250
)

# %%
plt.figure(3,figsize=(12,12)) 
nx.draw_circular(Dar,with_labels=True,node_size=1500, font_size=15,width=0.5)
plt.show()
